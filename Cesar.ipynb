# %% [markdown]
# # Python Assignment COP4020 001 15515

# %%
#Q1
print("Hello World")
# Out:
# Hello World

# %%
#Q2, Q3
age = 25
print(f"Hello World, im {age} today")
# Out:
# Hello World, im 25 today

# %%
#Q4
string = "hello world"
capString = " "

for c in string:
    capString+=c.upper()

print(capString)
# Out:
#  HELLO WORLD

# %%
#Q5
a = 1.2
b = int(a)
c = str(a)
print(a)
print(b)
print(c)
# Out:
# 1.2
# 1
# 1.2
